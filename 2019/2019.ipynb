# %%
import pandas as pd
import numpy as np
import xarray as xr
import scipy.stats as scipy
import os


#!pip install -U -q PyDrive

# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials
# # Authenticate and create the PyDrive client.
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# from google.colab import drive
# drive.mount("/content/drive")
# %cd /gdrive

# import os
from google.colab import drive
drive.mount('/content/drive')

files = os.listdir("/content/drive/My Drive/Datos_Brutos")
print()
print(files)

# # Definir el path a la *carpeta* 
# pth_originales = 'drive/My Drive/Trabajo de Grado/Tesis Oscar/Imagenes/Originales/'

def abrir(file):
  df=pd.read_csv(file+".txt", sep="\t")

# fil='/drive/My Drive/Datos Brutos/Variables_estacion'
# # abrir(fil)
# df=pd.read_csv("drive/My Drive/Datos_Brutos/Variables_estacion.txt", sep="\t")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-6ae0a8709bfc> in <module>()
#      26 drive.mount('/content/drive')
#      27
# ---> 28 files = os.listdir("/content/drive/My Drive/Datos_Brutos")
#      29 print()
#      30 print(files)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Datos_Brutos'
